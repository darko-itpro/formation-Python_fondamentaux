# %% [markdown]
# La POO

# %%
class MyClass:
    pass

# %%
MyClass()

# %%
class Training:
    def __init__(self, subject, seats=12):
        self.subject = subject
        self.students = []
        self.seats = seats

    def add_student(self, name):
        self.students.append(name)

    def our_students(self):
        return self.students.copy()

# %%
t = Training("Python")

# %%
t.our_students()
# Out:
# []

# %%
t.our_students
# Out:
# <bound method Training.our_students of <__main__.Training object at 0x1094d4c20>>

# %%
Training.our_students(t)
# Out:
# []

# %%
t.our_students()
# Out:
# []

# %%
Training.our_students
# Out:
# <function __main__.Training.our_students(self)>

# %%
class Bidule:
    pass

# %%
b = Bidule()

# %%
b.students = ["our students"]

# %%
b.students
# Out:
# ['our students']

# %%
Training.our_students(b)
# Out:
# ['our students']
