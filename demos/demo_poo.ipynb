# %% [markdown]
# # La Programmation Orientée Objet
#
# ## Introduction

# %%
class Training:
    
    def __init__(self, subject, duration, seats=12):
        self.subject = subject
        self.duration = duration
        self.max_seats = seats
        self.students = []

    def add_students(self, name):
        self.students.append(name)
    
    def reset_students(self):
        self.students.clear()
    
    def give_students(self):
        print(self.students)

# %%
t = Training("Python", 4, 7)

# %%
t.set_students()

# %%
t.students

# %%
t.give_students()

# %% [markdown]
# ## Explication du self

# %%
class Training:
    
    def __init__(self, subject, duration, seats=12):
        self.subject = subject
        self.duration = duration
        self.max_seats = seats
        self.students = []

    def add_students(self, name):
        self.students.append(name)
    
    def reset_students(self):
        self.students.clear()
    
    def give_students(self):
        print(self.students)

# %%
t = Training("Python", 5)

# %%
t.give_students()
# Out:
# []

# %%
t.give_students
# Out:
# <bound method Training.give_students of <__main__.Training object at 0x109865550>>

# %%
Training.give_students(t)
# Out:
# []

# %%
t.give_students()
# Out:
# []

# %%
class School:
    def __init__(self):
        self.students = "My Students"
    def give_students(self):
        print("No one")

# %%
s = School()

# %%
Training.give_students(s)
# Out:
# My Students

# %%
s.give_students()
# Out:
# No one

# %%
Training.reset_students(t)

# %%
Training.reset_students(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 Training.reset_students(s)
#
# Cell In[22], line 13, in Training.reset_students(self)
#      12 def reset_students(self):
# ---> 13     self.students.clear()
#
# AttributeError: 'str' object has no attribute 'clear'

# %%
help(Training)
# Out:
# Help on class Training in module __main__:
#
# class Training(builtins.object)
#  |  Training(subject, duration, seats=12)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, subject, duration, seats=12)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  add_students(self, name)
#  |
#  |  give_students(self)
#  |
#  |  reset_students(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
sl = """
bla bli
     tutu
"""

# %%
print(sl)
# Out:
# bla bli
#      tutu
