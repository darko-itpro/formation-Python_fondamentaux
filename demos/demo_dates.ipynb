# %% [markdown]
# # Les dates

# %%
from datetime import datetime, timedelta

# %%
instant = datetime(2024, 10, 2, 12, 46)

# %%
instant.year
# Out:
# 2024

# %%
instant.day
# Out:
# 2

# %%
instant.weekday()
# Out:
# 2

# %%
instant.isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2024, week=40, weekday=3)

# %%
maintenant = datetime.now()

# %%
xmas = datetime(2024, 12, 25)

# %%
to_xmas = xmas - datetime.now()

# %%
print(to_xmas)
# Out:
# 83 days, 7:23:31.311895

# %%
to_xmas.days
# Out:
# 83

# %%
to_xmas.microseconds
# Out:
# 311895

# %%
to_xmas.seconds
# Out:
# 26611

# %%
to_xmas.total_seconds()
# Out:
# 7197811.311895

# %%
coeuf = timedelta(minutes=3)

# %%
datetime.now() + coeuf
# Out:
# datetime.datetime(2024, 10, 2, 16, 44, 6, 100768)

# %%
maintenant
# Out:
# datetime.datetime(2024, 10, 2, 16, 35, 3, 907645)

# %%
maintenant.replace(year=2010)
# Out:
# datetime.datetime(2010, 10, 2, 16, 35, 3, 907645)

# %%
maintenant
# Out:
# datetime.datetime(2024, 10, 2, 16, 35, 3, 907645)
