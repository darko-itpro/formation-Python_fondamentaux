# %% [markdown]
# # Les listes
#
# ## Première partie

# %%
quizz = ["Meaning of life", 42]

# %%
len(quizz)
# Out:
# 2

# %%
quizz[0]
# Out:
# 'Meaning of life'

# %%
quizz[1]
# Out:
# 42

# %%
quizz[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 quizz[2]
#
# IndexError: list index out of range

# %%
quizz[1] = 42

# %%
quizz
# Out:
# ['Meaning of life', 42]

# %%
question, answer = ['Meaning of life', 42]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 question, answer = ['Meaning of life', 42, 2]
#
# ValueError: too many values to unpack (expected 2)

# %%
question
# Out:
# 'Meaning of life'

# %% [markdown]
# ## Deuxième partie

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
"Merlin" in camelot
# Out:
# True

# %%
camelot[-1]
# Out:
# 'Karadoc'

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot[1:4]
# Out:
# ['Merlin', 'Lancelot', 'Robin']

# %%
camelot[:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[-2:]
# Out:
# ['Perceval', 'Karadoc']

# %%
camelot[1::2]
# Out:
# ['Merlin', 'Robin', 'Karadoc']

# %%
camelot[::-1]
# Out:
# ['Karadoc', 'Perceval', 'Robin', 'Lancelot', 'Merlin', 'Arthur']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[0:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[2:4]
# Out:
# ['Lancelot', 'Robin']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot',]

# %%
camelot.append("Robin")

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin']

# %%
camelot.pop(0)
# Out:
# 'Arthur'

# %%
camelot
# Out:
# ['Merlin', 'Lancelot']

# %%
camelot.insert(1, "Arthur")

# %%
camelot
# Out:
# ['Merlin', 'Arthur', 'Lancelot']
