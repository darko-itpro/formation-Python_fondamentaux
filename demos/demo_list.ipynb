# %% [markdown]
# # Les listes

# %%
from pygame.examples.video import answer

quizz = ["Meaning of life", 42]

# %%
len(quizz)
# Out:
# 2

# %%
quizz[0]
# Out:
# 'Meaning of life'

# %%
quizz[1]
# Out:
# 42

# %%
quizz[-1]
# Out:
# 42

# %%
quizz[1] = 32

# %%
quizz
# Out:
# ['Meaning of life', 32]

# %%
question, answer = ['Meaning of life', 32]

# %%
question
# Out:
# 'Meaning of life'
