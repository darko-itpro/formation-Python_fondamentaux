# %%
from pathlib import Path

# %%
Path(".")
# Out:
# PosixPath('.')

# %%
curdir = Path(".")

# %%
curdir.resolve()
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux/demos/formation')

# %%
root_dir = curdir.resolve().parent.parent

# %%
root_dir
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux')

# %%
root_dir / "assets"
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux/assets')

# %%
assets_dir = root_dir.joinpath("assets")

# %%
for item in assets_dir.iterdir():
    print(type(item), item)
# Out:
# <class 'pathlib._local.PosixPath'> /Users/dad3zero/formation/formation-Python_fondamentaux/assets/bbts12.csv
# <class 'pathlib._local.PosixPath'> /Users/dad3zero/formation/formation-Python_fondamentaux/assets/showslist_uncomplete.csv
# <class 'pathlib._local.PosixPath'> /Users/dad3zero/formation/formation-Python_fondamentaux/assets/showslist_bad.csv
# <class 'pathlib._local.PosixPath'> /Users/dad3zero/formation/formation-Python_fondamentaux/assets/showsfiles.txt
# <class 'pathlib._local.PosixPath'> /Users/dad3zero/formation/formation-Python_fondamentaux/assets/files
# <class 'pathlib._local.PosixPath'> /Users/dad3zero/formation/formation-Python_fondamentaux/assets/showslist.csv

# %%
bbt_path = root_dir.joinpath("assets", "bbts12.csv")

# %%
bbt_path.open()
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/formation/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>

# %%
open(bbt_path)
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/formation/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>
