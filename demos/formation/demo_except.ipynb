# %%
value = "toto"

def convert(v):
    value = int(v)
    return value + 2

try:
    result = convert(value)
    print(result)
except KeyError:
    print("autre gestion")
except (ValueError, LookupError):
    print("géré")

print("done")
# Out:
# géré
# done
