# %% [markdown]
# # Les fonctions

# %%
def say_hello():
    print("Hello world")
    print("to all")

# %%
print(say_hello())
# Out:
# Hello world
# to all
# None

# %%
def give_hello() -> str:
    value = "Hello given"
    return value

# %%
print(give_hello())
# Out:
# Hello given

# %%
def say_hello_to(name:str):
    print("hello", name)

# %%
say_hello_to("john")
# Out:
# hello john
