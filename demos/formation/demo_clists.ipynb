# %%
from demos.demo_data import camelot

camelot = [("Arthur", "king"), ("Merlin", "wizard"),
           ("Lancelot", "knight"), ("Robin", "knight"),
           ("Perceval", "knight"), ("Karadoc", "knight")]

# %%
[name for name, job in camelot]
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
[(len(name), job) for name, job in camelot]
# Out:
# [(6, 'king'),
#  (6, 'wizard'),
#  (8, 'knight'),
#  (5, 'knight'),
#  (8, 'knight'),
#  (7, 'knight')]

# %%
[name for name, job in camelot if job != "wizard"]
# Out:
# ['Arthur', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
data = [name
        for name, job in camelot
        if job != "wizard"]

# %%
import pyflix.datasource as ds

potter_movies = ds.get_movies()

[title for title, _, _ in potter_movies]
# Out:
# ["The Philosopher's Stone",
#  'The Chamber of Secrets',
#  'The Prisoner of Azkaban',
#  'the Goblet of Fire',
#  'the Order of the Phoenix',
#  'the Half-Blood Prince',
#  'the Deathly Hallows – Part 1',
#  'the Deathly Hallows – Part 2']

# %%
[title for title, _, viewed in potter_movies if not viewed]
# Out:
# ['The Prisoner of Azkaban',
#  'the Order of the Phoenix',
#  'the Deathly Hallows – Part 1',
#  'the Deathly Hallows – Part 2']

# %%
sum([duration for _, duration, _ in potter_movies])
# Out:
# 1159

# %%
"Un marathon dure {}h{:02}".format(*divmod(sum([duration for _, duration, _ in potter_movies]), 60))
# Out:
# 'Un marathon dure 19h19'
