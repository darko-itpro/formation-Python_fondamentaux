# %% [markdown]
# # Les chaines de caractères

# %%
"Arthur"
# Out:
# 'Arthur'

# %%
'Arthur'
# Out:
# 'Arthur'

# %%
'l\'été'
# Out:
# "l'été"

# %%
king = "Arthur"

# %%
king.upper()
# Out:
# 'ARTHUR'

# %%
king.casefold()
# Out:
# 'arthur'

# %%
"Meaning of life".split()
# Out:
# ['Meaning', 'of', 'life']

# %%
"Meaning_of_life".split("_o")
# Out:
# ['Meaning', 'f_life']

# %%
"Meaning of    \n  life".split()
# Out:
# ['Meaning', 'of', 'life']

# %%
"Meaning of     life".split(" ")
# Out:
# ['Meaning', 'of', '', '', '', '', 'life']

# %%
" | ".join(['Meaning', 'of', 'life'])
# Out:
# 'Meaning | of | life'

# %%
"Meaning_of_life".replace('_', ' ')
# Out:
# 'Meaning of life'

# %%
"Prix : {:10.2f} {}".format(42, "€")
# Out:
# 'Prix :      42.00 €'

# %%
"Prix : {:.2f} {}".format(56.786, "€")
# Out:
# 'Prix : 56.79 €'

# %%
"Price : {1}{0:.2f}".format(52, "$")
# Out:
# 'Price : $52.00'

# %%
"{}h{:02}".format(9, 8)
# Out:
# '9h08'

# %% [markdown]
# # F Strings

# %%
value = 42
currency = "€"

# %%
f"Prix : {value:.2f} {currency}"
# Out:
# 'Prix : 42.00 €'

# %%
print(f"{currency=}")
# Out:
# currency='€'
