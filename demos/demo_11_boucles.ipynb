# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
for knight in camelot:
    print(knight.upper())
# Out:
# ARTHUR
# MERLIN
# LANCELOT
# ROBIN
# PERCEVAL
# KARADOC

# %%
for index, knight in enumerate(camelot):
    if index % 2:
        print("-", knight)
    else:
        print("*", knight)
# Out:
# * Arthur
# - Merlin
# * Lancelot
# - Robin
# * Perceval
# - Karadoc

# %%
for _ in range(4):
    print("turn left")
# Out:
# turn left
# turn left
# turn left
# turn left

# %%
value = 1
previous = 1

while value < 5000:
    print(value / previous)
    value, previous = value + previous, value
# Out:
# 1.0
# 2.0
# 1.5
# 1.6666666666666667
# 1.6
# 1.625
# 1.6153846153846154
# 1.619047619047619
# 1.6176470588235294
# 1.6181818181818182
# 1.6179775280898876
# 1.6180555555555556
# 1.6180257510729614
# 1.6180371352785146
# 1.618032786885246
# 1.618034447821682
# 1.6180338134001253
# 1.618034055727554

# %%
camelot = [("Arthur", "king"), ("Merlin", "wizard"),
           ("Lancelot", "knight"), ("Robin", "knight"),
           ("Perceval", "knight"), ("Karadoc", "knight")]

# %%
for name, job in camelot:
    print("Hail", name)
    if job == "wizard":
        continue
    print("He is a mighty knight")
# Out:
# Hail Arthur
# He is a mighty knight
# Hail Merlin
# Hail Lancelot
# He is a mighty knight
# Hail Robin
# He is a mighty knight
# Hail Perceval
# He is a mighty knight
# Hail Karadoc
# He is a mighty knight

# %%
for name, job in camelot:
    print(name)
    if job == "wizard":
        print('ok, you have a wizard')
        break
# Out:
# Arthur
# Merlin
# ok, you have a wizard

# %%
for name, job in camelot:
    print(name)
    if job == "wizard":
        print('ok, you have a wizard')
        break    
else:
    print('You NEEED a wizard')
# Out:
# Arthur
# Merlin
# ok, you have a wizard
