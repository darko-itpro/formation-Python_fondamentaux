# %% [markdown]
# # Fonctions…

# %%
def truc():
    return 42

# %%
value = truc

# %%
value
# Out:
# <function __main__.truc()>

# %%
value()
# Out:
# 42

# %%
i = 10

# %%
print(i)
# Out:
# 10

# %%
print = 20

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(i)
#
# TypeError: 'int' object is not callable

# %%
print
# Out:
# 20

# %%
del print

# %%
print(i)
# Out:
# 10

# %%
del print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del print
#
# NameError: name 'print' is not defined
