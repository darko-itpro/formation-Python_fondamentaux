# %% [markdown]
# # Namedtuples

# %%
from collections import namedtuple

# %%
Point = namedtuple("Point", ("x", "y", "z", "color"), 
                              defaults=(0,   None))

# %%
p = Point(3, 8)

# %%
p.z
# Out:
# 0

# %%
Point(3, 7, 9, 256)
# Out:
# Point(x=3, y=7, z=9, color=256)
