# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
'Robin' in camelot
# Out:
# True

# %%
camelot[1:4]
# Out:
# ['Merlin', 'Lancelot', 'Robin']

# %%
camelot[:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[-2:]
# Out:
# ['Perceval', 'Karadoc']

# %%
camelot[::2]
# Out:
# ['Arthur', 'Lancelot', 'Perceval']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[2:10]
# Out:
# ['Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[10:100]
# Out:
# []

# %%
camelot[::-1]
# Out:
# ['Karadoc', 'Perceval', 'Robin', 'Lancelot', 'Merlin', 'Arthur']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[0:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[2:4]
# Out:
# ['Lancelot', 'Robin']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
camelot.index('Robin')
# Out:
# 3

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot.append('Robin')

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin']

# %%
camelot.pop()
# Out:
# 'Robin'

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot.pop(0)
# Out:
# 'Arthur'

# %%
camelot
# Out:
# ['Merlin', 'Lancelot']

# %%
camelot.insert(1, "Robin")

# %%
camelot
# Out:
# ['Merlin', 'Robin', 'Lancelot']

# %%
camelot.append(["Perceval", "Karadoc"])

# %%
camelot
# Out:
# ['Merlin', 'Robin', 'Lancelot', ['Perceval', 'Karadoc']]

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot.extend(["Perceval", "Karadoc"])

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Perceval', 'Karadoc']

# %%
camelot.extend('Pendragon')

# %%
camelot
# Out:
# ['Arthur',
#  'Merlin',
#  'Lancelot',
#  'Perceval',
#  'Karadoc',
#  'P',
#  'e',
#  'n',
#  'd',
#  'r',
#  'a',
#  'g',
#  'o',
#  'n']

# %%
camelot.extend(camelot)

# %%
camelot
# Out:
# ['Arthur',
#  'Merlin',
#  'Lancelot',
#  'Perceval',
#  'Karadoc',
#  'P',
#  'e',
#  'n',
#  'd',
#  'r',
#  'a',
#  'g',
#  'o',
#  'n',
#  'Arthur',
#  'Merlin',
#  'Lancelot',
#  'Perceval',
#  'Karadoc',
#  'P',
#  'e',
#  'n',
#  'd',
#  'r',
#  'a',
#  'g',
#  'o',
#  'n']

# %%
'a' == 'A'
# Out:
# False

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot.sort()

# %%
camelot
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
sorted(camelot)
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
demo_lambda = lambda x: x * 2

# %%
demo_lambda(4)
# Out:
# 8

# %%
sorted(camelot, key=len)
# Out:
# ['Robin', 'Arthur', 'Merlin', 'Karadoc', 'Lancelot', 'Perceval']
