# %%
king = "Arthur"

# %%
len(king)
# Out:
# 6

# %%
king[1]
# Out:
# 'r'

# %%
king.upper()
# Out:
# 'ARTHUR'

# %%
king
# Out:
# 'Arthur'

# %%
"Meaning of           life".split()
# Out:
# ['Meaning', 'of', 'life']

# %%
"Meaning of           life".split(' ')
# Out:
# ['Meaning', 'of', '', '', '', '', '', '', '', '', '', '', 'life']

# %%
"Meaning_of_life".split('_o')
# Out:
# ['Meaning', 'f_life']

# %%
" ".join(['Meaning', 'of', 'life'])
# Out:
# 'Meaning of life'

# %%
"Meaning_of_life".replace('_', ' ')
# Out:
# 'Meaning of life'

# %%
"Prix : {:.2f} {}".format(42, "€")
# Out:
# 'Prix : 42.00 €'

# %%
"Prix : {:.2f} {}".format(42.568, "€")
# Out:
# 'Prix : 42.57 €'

# %%
"Price: {1}{0:.2f}".format(42, "$")
# Out:
# 'Price: $42.00'

# %%
"IL est {}h{:02}".format(5, 7)
# Out:
# 'IL est 5h07'

# %%
value = 42
currency = "€"

f"Prix : {value:.2f} {currency}"
# Out:
# 'Prix : 42.00 €'
