# %% [markdown]
# # Pathlib

# %%
from pathlib import Path

# %%
Path('.')

# %%
p = Path('.')

# %%
p.resolve()

# %%
p

# %%
p.resolve().parent

# %%
p_assets = p.resolve().parent / "assets"

# %%
p_assets

# %%
p_assets.exists()

# %%
p.resolve().parent.joinpath("assets", "bbts12.csv")

# %%
for item in p_assets.iterdir():
    print(type(item), item)

# %%
    open(p.resolve().parent.joinpath("assets", "bbts12.csv"))
