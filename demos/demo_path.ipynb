# %%
from pathlib import Path

# %%
Path(".")
# Out:
# PosixPath('.')

# %%
Path('.').resolve()
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux/demos')

# %%
Path('.').resolve().parent
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux')

# %%
Path('.').resolve().parent / "assets"
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux/assets')

# %%
project_dir = Path('.').resolve().parent

# %%
project_dir / "assets"
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux/assets')

# %%
file_path = project_dir.joinpath("assets", "bbts12.csv")

# %%
file_path.exists()
# Out:
# True

# %%
file_path.is_file()
# Out:
# True

# %%
project_dir.is_dir()
# Out:
# True

# %%
for item in project_dir.iterdir():
    print(type(item))
# Out:
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>

# %%
file_path.open()
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/formation/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>

# %%
open(file_path)
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/formation/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>

# %%
print(file_path)
# Out:
# /Users/dad3zero/formation/formation-Python_fondamentaux/assets/bbts12.csv

# %%
file_path.stem
# Out:
# 'bbts12'

# %%
file_path.suffix
# Out:
# '.csv'

# %%
file_path.with_suffix(".bak")
# Out:
# PosixPath('/Users/dad3zero/formation/formation-Python_fondamentaux/assets/bbts12.bak')
