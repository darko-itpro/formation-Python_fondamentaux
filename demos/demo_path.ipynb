# %% [markdown]
# # Pathlib

# %%
from pathlib import Path

# %%
p_current = Path('.')

# %%
p_current.resolve()
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/demos')

# %%
import os
os.chdir("..")

# %%
p_current.resolve()
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux')

# %%
p_current.resolve().parent
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations')

# %%
p_current.resolve() / "assets"
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets')

# %%
p_current.resolve().joinpath("assets")
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets')

# %%
p_current.resolve().joinpath("assets", "bbts12.csv").exists()
# Out:
# True

# %%
p_current.resolve().joinpath("assets", "bbts12.csv").open()
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>

# %%
open(p_current.resolve().joinpath("assets", "bbts12.csv"))
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>

# %%
p_current.resolve().joinpath("assets", "bbts12.csv").with_suffix('.txt')
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets/bbts12.txt')

# %%
for item in p_current.resolve().joinpath("assets").iterdir():
    print(type(item))
# Out:
# <class 'pathlib.PosixPath'>
# <class 'pathlib.PosixPath'>
# <class 'pathlib.PosixPath'>
# <class 'pathlib.PosixPath'>
# <class 'pathlib.PosixPath'>
# <class 'pathlib.PosixPath'>

# %%
p_current.resolve().joinpath("assets").drive
# Out:
# ''
