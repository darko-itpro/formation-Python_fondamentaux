# %%
from exos.pyflix.mediatheque import TvShow
import pyflix.datasource as ds

# %%
show = TvShow('Arcane')

# %%
for item in ds.load_show("Arcane"):
    show.add_episode(*item[1:])

# %%
len(show.episodes)
# Out:
# 18

# %%
show.episodes[0].title
# Out:
# 'Welcome to the Playground'

# %%
def func(*args):
    print(args)

# %%
func(1, 2, param=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 func(1, 2, param=3)
#
# TypeError: func() got an unexpected keyword argument 'param'

# %%
def func(**kwargs):
    print(kwargs)

# %%
func(param=2)
# Out:
# {'param': 2}
