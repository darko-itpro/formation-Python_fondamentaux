# %% [markdown]
# # Les imports

# %%
episode_not_viewed = ['Installing the softwares', 2, 42, 0]

# %%
import exos_correction.base.episode_utils
exos_correction.base.episode_utils.is_viewed(episode_not_viewed)
# Out:
# False

# %%
from exos_correction.base import episode_utils
episode_utils.is_viewed(episode_not_viewed)
# Out:
# False

# %%
import exos_correction.base.episode_utils as eu
eu.is_viewed(episode_not_viewed)
# Out:
# False

# %%
from exos_correction.base.episode_utils import is_viewed
is_viewed(episode_not_viewed)
# Out:
# False

# %%
network = get_network()

if network:
    import ws_utils as datasource
else:
    import local_cache as datasource

datasource.save(data)
