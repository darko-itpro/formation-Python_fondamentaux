# %% [markdown]
# # Les chaines de caractères

# %%
"Arthur"
# Out:
# 'Arthur'

# %%
'Arthur'
# Out:
# 'Arthur'

# %%
"l'été"
# Out:
# "l'été"

# %%
king = 'Arthur'

# %%
len(king)
# Out:
# 6

# %%
king[2]
# Out:
# 't'

# %%
king.upper()
# Out:
# 'ARTHUR'

# %%
king
# Out:
# 'Arthur'

# %%
"Meaning_of_life".split("_o")
# Out:
# ['Meaning', 'f_life']

# %%
"Meaning of    \n    life".split()
# Out:
# ['Meaning', 'of', 'life']

# %%
"Meaning of          life".split(" ")
# Out:
# ['Meaning', 'of', '', '', '', '', '', '', '', '', '', 'life']

# %%
" - ".join(['Meaning', 'of', 'life'])
# Out:
# 'Meaning - of - life'

# %%
''.join(['Meaning', 'of', 'life'])
# Out:
# 'Meaningoflife'

# %%
PRICE_FR = "prix : {:10.2f} {}"
PRICE_FR.format(42, "€")
# Out:
# 'prix :      42.00 €'

# %%
PRICE_FR.format(45.987, "€")
# Out:
# 'prix : 45.99 €'

# %%
PRICE_US = "Price: {1}{0:.2f}"

PRICE_US.format(56, "$")
# Out:
# 'Price: $56.00'

# %%
"{:02}h{:02}".format(16, 8)
# Out:
# '16h08'

# %%
value = 42
currency = "€"

# %%
f"Prix : {value:.2f} {currency}"
# Out:
# 'Prix : 42.00 €'

# %% [markdown]
# ## Exercices
#
# ### Vitesse

# %%
distance = 19.7
duration = 6.892

print("Vitesse de {:.2f} m/s".format(distance / duration))
print(f"Vitesse de {distance / duration:.2f} m/s")
# Out:
# Vitesse de 2.86 m/s
# Vitesse de 2.86 m/s

# %% [markdown]
# ### Heure coucher
