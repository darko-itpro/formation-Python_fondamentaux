# %%
def calculate(value:int):
    """
    :except ValueError: 
    """
    if value < 0:
        raise ValueError('negative value')
    return value + 1
    
user_input = -42
    
try:
    v = calculate(user_input)
    print(v)
except IndexError:
    print("J'ai géré autrement")
except (ValueError, LookupError):
    print("c'est bon c'est géré")
# Out:
# c'est bon c'est géré

# %%
del v
