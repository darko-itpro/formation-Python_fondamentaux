# %% [markdown]
# # Les boucles avec for

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
king, wizard, *knights = camelot
print(knights)
# Out:
# ['Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
for knight in camelot:
    print(knight)
# Out:
# Arthur
# Merlin
# Lancelot
# Robin
# Perceval
# Karadoc

# %%
for index, knight in enumerate(camelot):
    if index % 2:
        print(">",knight)
    else:
        print("-",knight)
# Out:
# - Arthur
# > Merlin
# - Lancelot
# > Robin
# - Perceval
# > Karadoc

# %%
knight
# Out:
# 'Karadoc'

# %%
for _ in range(4):
    print("turn left")
# Out:
# 0
# 1
# 2
# 3

# %%
camelot = [("Arthur", "king"), ("Merlin", "wizard"),
           ("Lancelot", "knight"), ("Robin", "knight"),
           ("Perceval", "knight"), ("Karadoc", "knight")]


for name, job in camelot:
    print("Hail", name)
    if job == "wizard":
        continue
    print("He is a proud knight")
# Out:
# Hail Arthur
# He is a proud knight
# Hail Merlin
# Hail Lancelot
# He is a proud knight
# Hail Robin
# He is a proud knight
# Hail Perceval
# He is a proud knight
# Hail Karadoc
# He is a proud knight

# %%
for name, job in camelot:
    print(name)
    if job == "wizad":
        print("you have a wizard")
        break    
else:
    print("You need a wizard")
# Out:
# Arthur
# Merlin
# Lancelot
# Robin
# Perceval
# Karadoc
# You need a wizard

# %%
camelot = [("Arthur", "king"), ("Merlin", "wizard"),
           ("Lancelot", "knight"), ("Robin", "knight"),
           ("Perceval", "knight"), ("Karadoc", "knight")]

# %%
[len(name) for name, job in camelot]
# Out:
# [6, 6, 8, 5, 8, 7]

# %%
[(name, job) for name, job in camelot if job != "wizard"]
# Out:
# [('Arthur', 'king'),
#  ('Lancelot', 'knight'),
#  ('Robin', 'knight'),
#  ('Perceval', 'knight'),
#  ('Karadoc', 'knight')]

# %%
import pyflix.datasource as ds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import pyflix.datasource as ds
#
# ModuleNotFoundError: No module named 'pyflix.datasource'
