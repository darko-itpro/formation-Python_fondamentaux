# %%
class MyClass:
    pass

# %%
MyClass()

# %%
mc = MyClass()

# %%
mc

# %%
print(mc)

# %%
class Training:
    def __init__(self, subject):
        self.subject = subject
        self.students = []

    def display_name(self):
        print("My training is", self.subject)

# %%
t = Training("Python")

# %%
t.display_name
# Out:
# <bound method Training.display_name of <__main__.Training object at 0x107edf8c0>>

# %%
Training.display_name(t)
# Out:
# My training is Python

# %%
t.display_name()
# Out:
# My training is Python

# %%
class Truc:
    def __init__(self):
        self.subject = "gigi"

# %%
tr = Truc()

# %%
Training.display_name(tr)
# Out:
# My training is gigi
