# %% [markdown]
# # Dictionnaires

# %%
camelot = {"king":"Arthur", "wizard":"Merlin"}

# %%
len(camelot)
# Out:
# 2

# %%
camelot["king"]
# Out:
# 'Arthur'

# %%
camelot['queen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 camelot['queen']
#
# KeyError: 'queen'

# %%
camelot['king'] = "Pendragon"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin'}

# %%
camelot['queen'] = "Gueniever"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin', 'queen': 'Gueniever'}

# %%
camelot["knights"] = ["Lacelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot
# Out:
# {'king': 'Pendragon',
#  'wizard': 'Merlin',
#  'queen': 'Gueniever',
#  'knights': ['Lacelot', 'Robin', 'Perceval', 'Karadoc']}

# %%
camelot['knights'][2]
# Out:
# 'Perceval'

# %%
"queen" in camelot
# Out:
# True

# %%
"vilain" in camelot
# Out:
# False

# %%
sentence = "the Holy Grenade, you should count to three and three shall be the number"

# %%
occurences = {}

words = sentence.split()

for word in words:
    occurences[word] = occurences.get(word, 0) + 1

# %%
occurences
# Out:
# {'The': 1,
#  'Holy': 1,
#  'Grenade,': 1,
#  'you': 1,
#  'should': 1,
#  'count': 1,
#  'to': 1,
#  'three': 2,
#  'and': 1,
#  'shall': 1,
#  'be': 1,
#  'the': 1,
#  'number': 1}
