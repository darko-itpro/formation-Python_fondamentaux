# %% [markdown]
# # Les lists

# %%
quizz = ["Meaning of life", 42]

# %%
len(quizz)
# Out:
# 2

# %%
quizz[0]
# Out:
# 'Meaning of life'

# %%
quizz[1]
# Out:
# 42

# %%
quizz[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 quizz[2]
#
# IndexError: list index out of range

# %%
quizz[1] = 52

# %%
quizz
# Out:
# ['Meaning of life', 52]

# %%
quizz = ["Meaning of life", 42]

# %%
question, answer = ["Meaning of life", 42]

# %%
question
# Out:
# 'Meaning of life'

# %%
answer
# Out:
# 42

# %% [markdown]
# ## Seconde partie

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
len(camelot)
# Out:
# 6

# %%
"Lancelot" in camelot
# Out:
# True

# %%
camelot[-1]
# Out:
# 'Karadoc'

# %% [markdown]
# ## Slicing

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[1:4]
# Out:
# ['Merlin', 'Lancelot', 'Robin']

# %%
camelot[20:100]
# Out:
# []

# %%
camelot[:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[3:]
# Out:
# ['Robin', 'Perceval', 'Karadoc']

# %%
camelot[-2:]
# Out:
# ['Perceval', 'Karadoc']

# %%
camelot[:]
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[::2]
# Out:
# ['Arthur', 'Lancelot', 'Perceval']

# %%
camelot[::-1]
# Out:
# ['Karadoc', 'Perceval', 'Robin', 'Lancelot', 'Merlin', 'Arthur']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[0:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[2:4]
# Out:
# ['Lancelot', 'Robin']

# %% [markdown]
# ## Modification de listes

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot.append("Robin")

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin']

# %%
camelot.pop()
# Out:
# 'Robin'

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot.pop(0)
# Out:
# 'Arthur'

# %%
camelot
# Out:
# ['Merlin', 'Lancelot']

# %%
del camelot[0]

# %%
camelot
# Out:
# ['Lancelot']

# %%
camelot = ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot.insert(1, "Perceval")

# %%
camelot
# Out:
# ['Arthur', 'Perceval', 'Merlin', 'Lancelot']
