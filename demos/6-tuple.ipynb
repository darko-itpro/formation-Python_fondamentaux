# %% [markdown]
# # Les tuples

# %%
v = 1, 2, 3

# %%
type(v)
# Out:
# tuple

# %%
v = 1,

# %%
type(v)
# Out:
# tuple

# %%
v
# Out:
# (1, 2, 3)

# %%
def func():
    return 1, 2, 3

func()
# Out:
# (1, 2, 3)

# %%
question = 42
answer = "Meaning of life"

# %%
question, answer = answer, question

# %%
question
# Out:
# 'Meaning of life'
