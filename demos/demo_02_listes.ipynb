# %% [markdown]
# # Les listes

# %%
quizz = ["Meaning of life", 42]

# %%
len(quizz)
# Out:
# 2

# %%
quizz[0]
# Out:
# 'Meaning of life'

# %%
quizz[1]
# Out:
# 42

# %%
quizz[1] = 52

# %%
quizz
# Out:
# ['Meaning of life', 52]

# %%
quizz = ["Meaning of life", 42]

# %%
question = quizz[0]
answer = quizz[1]

# %%
question, answer = ["Meaning of life", 42]

# %%
question
# Out:
# 'Meaning of life'

# %%
answer
# Out:
# 42
