# %%
file_path = "../../file.log"

# %%
my_file = open(file_path)

# %%
my_file.close()

# %%
my_file = open(file_path)

# %%
my_file.read()

# %%
my_file.seek(0)

# %%
my_file.read(5)

# %%
my_file.readline(15)

# %%
my_file.readlines()

# %%
with open(file_path) as my_file:
    for line in my_file:
        print(line.strip())

# %% [markdown]
# ## Pathlib

# %%
from pathlib import Path

# %%
Path('.')
# Out:
# PosixPath('.')

# %%
current = Path('.')

# %%
current.resolve()
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/demos/bases')

# %%
current.resolve().parent
# Out:
# PosixPath('/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/demos')

# %%
assets_path = current.resolve().parent.parent / "assets"

# %%
bbt_path = (current.resolve().parent.parent).joinpath('assets', "bbts12.csv")

# %%
bbt_path.exists()
# Out:
# True

# %%
assets_path.is_dir()
# Out:
# True

# %%
for item in assets_path.iterdir():
    print(type(item))
# Out:
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>
# <class 'pathlib._local.PosixPath'>

# %%
bbt_path.is_file()
# Out:
# True

# %%
bbt_path.open()
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>

# %%
open(bbt_path)
# Out:
# <_io.TextIOWrapper name='/Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets/bbts12.csv' mode='r' encoding='UTF-8'>

# %%
print(bbt_path)
# Out:
# /Users/dad3zero/Workshop/formations/formation-Python_fondamentaux/assets/bbts12.csv

# %%
Path('/riri/fifi')
# Out:
# PosixPath('/riri/fifi')
