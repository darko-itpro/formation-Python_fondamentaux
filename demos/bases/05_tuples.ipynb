# %% [markdown]
# # Les N-uplets (tuples)

# %%
value = 1, 2, 3

# %%
type(value)
# Out:
# tuple

# %%
value
# Out:
# (1, 2, 3)

# %%
def truc():
    return 42, "meaning of life"

# %%
answer = "meaning of life"
question = 24

# %%
question, answer = answer, question
