# %% [markdown]
# # La Programmaton orientée objet

# %%
class Training:
    def __init__(self, name:str, seats=12):
        self.subject = name
        self.seats = seats
        self.students = []

    def add_student(self, name:str):
        self.students.append(name)

# %%
t = Training("Python")

# %%
t.display_subject()
# Out:
# Python

# %%
t.subject
# Out:
# 'Python'
