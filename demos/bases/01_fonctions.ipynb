# %% [markdown]
# # Fonctions

# %%
from pymdownx import caret


def say_hello():
    print("Hello World")

def give_hello():
    value = "Hello Given"
    return value, 1

def say_hello_to(name):
    print("Hello", name)

# %%
def say_hello(name="World"):
    print("Hello", name)

# %%
say_hello()
say_hello("Guido")

# %%
def create_account(id:str, value:float = 100, overdraft:bool = False):
    print(id, value, overdraft)

# %%
create_account("My id", 100000, True)
create_account("My id", 100000)
create_account("My id")

# %%
create_account("my id", overdraft=True)

# %% [markdown]
# ## Approche fonctionnelle

# %%
def func():
    return 42

# %%
value = func

# %%
value()

# %%
value = 10

# %%
value()

# %%
i = 10

# %%
print(i)
# Out:
# 10

# %%
print = 42

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(i)
#
# TypeError: 'int' object is not callable

# %%
print
# Out:
# 42

# %%
del print

# %%
print(i)
# Out:
# 10

# %%
del print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del print
#
# NameError: name 'print' is not defined
