# %%
def triple_plus_one(a, b):
    print(a * 3 + b)

# %%
triple_plus_one(2, 3)
# Out:
# 9

# %%
triple_plus_one("Hip ", "Hourra")
# Out:
# Hip Hip Hip Hourra

# %%
king = "Arthur"

# %%
hasattr(king, "upper")
# Out:
# True

# %%
for attr in dir(king):
    if attr.startswith("is"):
        print(attr, getattr(king, attr)())
# Out:
# isalnum True
# isalpha True
# isascii True
# isdecimal False
# isdigit False
# isidentifier True
# islower False
# isnumeric False
# isprintable True
# isspace False
# istitle True
# isupper False
