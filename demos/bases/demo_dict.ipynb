# %% [markdown]
# # Les dictionnaires

# %%
camelot = {"king": "Arthur", "wizard": "Merlin"}

# %%
type(camelot)
# Out:
# dict

# %%
len(camelot)
# Out:
# 2

# %%
camelot["king"]
# Out:
# 'Arthur'

# %%
camelot['queen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 camelot['queen']
#
# KeyError: 'queen'

# %%
"Arthur" in camelot
# Out:
# False

# %%
camelot["king"] = "Pendragon"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin'}

# %%
camelot["queen"] = "Guienever"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin', 'queen': 'Guienever'}

# %%
camelot['knights'] = ["Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot
# Out:
# {'king': 'Pendragon',
#  'wizard': 'Merlin',
#  'queen': 'Guienever',
#  'knights': ['Lancelot', 'Robin', 'Perceval', 'Karadoc']}

# %%
camelot["knights"][0]
# Out:
# 'Lancelot'
