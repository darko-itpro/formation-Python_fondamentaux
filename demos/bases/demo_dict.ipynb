# %% [markdown]
# # Les dictionnaires

# %%
type({})
# Out:
# dict

# %%
camelot = {"king":"Arthur", "wizard":"Merlin"}

# %%
len(camelot)
# Out:
# 2

# %%
"Arthur" in camelot
# Out:
# False

# %%
camelot["king"]
# Out:
# 'Arthur'

# %%
camelot['queen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 camelot['queen']
#
# KeyError: 'queen'

# %%
camelot['king'] = "Pendragon"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin'}

# %%
camelot['queen'] = "Guenioever"
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin', 'queen': 'Guenioever'}

# %%
camelot['knights'] = ["Lancelot", "Robin"]

# %%
camelot
# Out:
# {'king': 'Pendragon',
#  'wizard': 'Merlin',
#  'queen': 'Guenioever',
#  'knights': ['Lancelot', 'Robin']}

# %%
camelot["knights"][0]
# Out:
# 'Lancelot'

# %%
sentence = "une phrade"
counting = {"une": 12}

counting["une"] = counting["une"] + 1

# %%
print(counting.get("une", 0))
# Out:
# 13
