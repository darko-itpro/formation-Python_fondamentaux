# %% [markdown]
# # Type de données
#
# ## Namedtuple

# %%
from collections import namedtuple

Point = namedtuple("Point", "x y z color", defaults=[0, None])

# %%
p = Point(3, 6)

# %%
p.y
# Out:
# 6

# %%
p.color
# Out:
# 255

# %%
p[2]
# Out:
# 8

# %%
print(*p)
# Out:
# 3 6 8 255
