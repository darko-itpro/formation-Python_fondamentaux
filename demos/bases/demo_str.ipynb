# %% [markdown]
# # Les chaines de caractères

# %%
king = ("Arthur")

# %%
king[::-1]
# Out:
# 'ruhtrA'

# %%
king.upper()
# Out:
# 'ARTHUR'

# %%
king.casefold()
# Out:
# 'arthur'

# %%
''Meaning of life'
