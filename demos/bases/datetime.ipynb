# %% [markdown]
# # Les dates en Python

# %%
from datetime import datetime, timedelta

# %%
xmas = datetime(2026, 12, 25)

# %%
xmas.weekday()
# Out:
# 4

# %%
today = datetime.now()

# %%
today
# Out:
# datetime.datetime(2026, 9, 11, 11, 15, 36, 994736)

# %%
today.weekday()
# Out:
# 4

# %%
today.isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2026, week=37, weekday=5)

# %%
to_xmas = xmas - today

# %%
to_xmas
# Out:
# datetime.timedelta(days=104, seconds=45863, microseconds=5264)

# %%
to_xmas.total_seconds()
# Out:
# 9031463.005264

# %%
today.replace(month=10)
# Out:
# datetime.datetime(2026, 10, 11, 11, 15, 36, 994736)

# %%
today
# Out:
# datetime.datetime(2026, 9, 11, 11, 15, 36, 994736)

# %%
today.strftime("%y/%m/%d %H:%M")
# Out:
# '26/09/11 11:15'

# %%
datetime.strptime("2/6/2027", "%d/%m/%Y")
# Out:
# datetime.datetime(2027, 6, 2, 0, 0)

# %%
timedelta(minutes=7*24)
# Out:
# datetime.timedelta(seconds=10080)

# %%
today
# Out:
# datetime.datetime(2026, 9, 11, 11, 15, 36, 994736)

# %%
print(f"{today:%H:%m}")
# Out:
# 11:09

# %%
print(today)
# Out:
# 2026-09-11 11:15:36.994736
