# %% [markdown]
# # Les listes

# %%
type([])
# Out:
# list

# %%
quizz = ["Meaning of life ?", 42]

# %%
len(quizz)
# Out:
# 2

# %%
quizz[1]
# Out:
# 42

# %%
quizz[1] = 43

# %%
quizz
# Out:
# ['Meaning of life ?', 43]

# %%
43 in quizz
# Out:
# True

# %%
question, answer = ["Meaning of life ?", 42]

# %%
question
# Out:
# 'Meaning of life ?'

# %%
question, answer = quizz
