# %% [markdown]
# # Exceptions

# %%
training = []
max_students = 10

def add_student(name:str, training:list, max:int):
    if len(training) >= max:
        raise ValueError('Training full')
    training.append(name)

# %%
add_student('toto', training, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 add_student('toto', training, 3)
#
# Cell In[21], line 6, in add_student(name, training, max)
#       4 def add_student(name:str, training:list, max:int):
#       5     if len(training) >= max:
# ----> 6         raise ValueError('Training full')
#       7     training.append(name)
#
# ValueError: Training full

# %%
training
# Out:
# ['toto', 'toto', 'toto']
