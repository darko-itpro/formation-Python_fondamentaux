# %% [markdown]
# # Exceptions

# %%
input_value = "dix"

def transform(data):
    return int(data) + 2

try:
    value = transform(input_value)
except KeyError:
    print("autre chose")
except (ValueError, LookupError):
    print("Managed")

print("done")
# Out:
# Managed
# done
