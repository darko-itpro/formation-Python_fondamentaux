# %% [markdown]
# # Les listes, seconde partie

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
len(camelot)
# Out:
# 6

# %%
"Lancelot" in camelot
# Out:
# True

# %%
camelot[-1]
# Out:
# 'Karadoc'

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot[1:4]
# Out:
# ['Merlin', 'Lancelot', 'Robin']

# %%
camelot[:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[3:]
# Out:
# ['Robin', 'Perceval', 'Karadoc']

# %%
camelot[-2:]
# Out:
# ['Perceval', 'Karadoc']

# %%
camelot[10:100]
# Out:
# []

# %%
camelot[:]
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']

# %%
camelot[::2]
# Out:
# ['Arthur', 'Lancelot', 'Perceval']

# %%
camelot[6:2:-1]
# Out:
# ['Karadoc', 'Perceval', 'Robin']

# %%
camelot[::-1]
# Out:
# ['Karadoc', 'Perceval', 'Robin', 'Lancelot', 'Merlin', 'Arthur']

# %%
"Aryhur"[::-1]
# Out:
# 'ruhyrA'

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot[0:2]
# Out:
# ['Arthur', 'Merlin']

# %%
camelot[2:4]
# Out:
# ['Lancelot', 'Robin']

# %%
camelot.count("Lancelot")
# Out:
# 1

# %%
camelot = ["Arthur", "Merlin", "Lancelot"]

# %%
camelot.append("Karadoc")

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Karadoc']

# %%
camelot.pop()
# Out:
# 'Karadoc'

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot']

# %%
camelot.pop(0)
# Out:
# 'Arthur'

# %%
camelot
# Out:
# ['Merlin', 'Lancelot']

# %%
camelot.insert(1, "Arthur")

# %%
camelot
# Out:
# ['Merlin', 'Arthur', 'Lancelot']

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot.sort()

# %%
camelot
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
sorted(camelot)
# Out:
# ['Arthur', 'Karadoc', 'Lancelot', 'Merlin', 'Perceval', 'Robin']

# %%
camelot
# Out:
# ['Arthur', 'Merlin', 'Lancelot', 'Robin', 'Perceval', 'Karadoc']
