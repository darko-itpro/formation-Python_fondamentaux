# %%
file_path = ""

# %%
my_file = open(file_path, "rt")

# %%
my_file.read()

# %%
my_file.close()

# %%
my_file.seek(0)

# %%
len('🧑‍🧑‍🧒')

# %%
'🧑‍🧑‍🧒'[::-1]

# %%
my_file.read(5)

# %%
my_file.readline()

# %%
my_file.readlines()

# %%
my_file.seek(0)

# %%
for line in my_file:
    print(line.strip())

# %%
with open(file_path, "rt") as my_file:
    for line in my_file:
        print(line.strip())

# %%
import os

os.listdir("../pyflix")

# %%
open(os.listdir("../pyflix")[0])

# %%
os.path.join("riri", "fifi")

# %%
for item in os.scandir("../pyflix"):
    print(item)

# %%
help(os.DirEntry)

# %%
os.path.dirname('riri/fifi/louoou.txt')

# %%
os.path.basename('riri/fifi/louoou.txt')

# %%
os.path.split('riri/fifi/louoou.txt')

# %%
os.path.splitext('riri/fifi/louoou.txt')
