# %% [markdown]
# # Les Listes, partie

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
"Merlin" in camelot

# %%
len(camelot)

# %%
camelot[0]

# %%
camelot[-1]

# %%
camelot[-2]

# %% [markdown]
# ## Extrait de liste

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot[1:4]

# %%
camelot[10:50]

# %%
camelot[:2]

# %%
camelot[3:]

# %%
camelot[-2:]

# %%
camelot[:]

# %%
camelot[::2]

# %%
camelot[::-1]

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot[0:2]

# %%
camelot[2:4]

# %%
camelot = ["Arthur", "Merlin", "Lancelot"]

# %%
camelot.append("Karadoc")

# %%
camelot

# %%
camelot.pop()

# %%
camelot

# %%
camelot.pop(0)

# %%
camelot

# %%
camelot.insert(5, "Arthur")

# %%
camelot

# %%
import pyflix.datasource as ds

bbt_s12 = ds.get_season()

# %%
bbt_s12

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot.sort()

# %%
camelot

# %%
camelot = ["Arthur", "Merlin", "Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
sorted(camelot)

# %%
camelot

# %%
camelot = []

def add_knight(name, kingdom):
    kingdom.append(name)

add_knight("Karadoc", camelot)
print(camelot)

# %%
i = 10

def truc():
    global i
    i = i + 2
    print(i)

truc()

# %%
i

# %%
kingdom = []

def add_knight(name):
    kingdom.append(name)

add_knight("Karadoc")
print(kingdom)
# Out:
# ['Karadoc']
