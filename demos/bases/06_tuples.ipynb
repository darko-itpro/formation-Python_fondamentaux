# %% [markdown]
# # Les N-Uplets (tuples)

# %%
value = 1, 2, 3,

# %%
type(value)
# Out:
# tuple

# %%
value
# Out:
# (1, 2, 3)

# %%
def func():
    return 1, 2, 3

# %%
answer = "Meaning of life"
question = 42

# %%
answer, question = question, answer

# %%
answer
# Out:
# 42
