# %% [markdown]
# # Les fonctions

# %%
def say_hello():
    print("Hello World!")
    print("To all")

# %%
print(say_hello())
# Out:
# Hello World!
# To all
# None

# %%
def give_hello():
    value = "Hello given"
    return value

# %%
returned_value = give_hello()
print(returned_value)
# Out:
# Hello given

# %%
def say_hello_to(name:str):
    print("Hello", name)

# %%
say_hello_to("Me")
# Out:
# Hello Me
