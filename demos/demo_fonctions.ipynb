# %% [markdown]
# # Les fonctions

# %%
def say_hello():
    print("Hello World")
    print("To all")

say_hello()

# %%
say_hello()
# Out:
# Hello World
# To all
# None

# %%
def give_hello():
    value = "Hello given"
    return value

# %%
print(give_hello())
# Out:
# None

# %%
def say_hello_to(name:str):
    print("Hello", name)

say_hello_to("John")
# Out:
# Hello John
