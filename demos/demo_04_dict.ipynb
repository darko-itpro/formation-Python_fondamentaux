# %% [markdown]
# # Les dictionnaires

# %%
type({})
# Out:
# dict

# %%
camelot = {"king":"Arthur", "wizard":"Merlin"}

# %%
len(camelot)
# Out:
# 2

# %%
camelot["king"]
# Out:
# 'Arthur'

# %%
camelot['queen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 camelot['queen']
#
# KeyError: 'queen'

# %%
camelot['king'] = 'Pendragon'

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin'}

# %%
camelot['queen'] = "Geniever"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin', 'queen': 'Geniever'}

# %%
del camelot['king']

# %%
camelot
# Out:
# {'wizard': 'Merlin', 'queen': 'Geniever'}

# %%
camelot['king'] = "Arthur"

# %%
"king" in camelot
# Out:
# True

# %%
"Arthur" in camelot
# Out:
# False

# %%
camelot['knights'] = ["Lancelot", "Robin", "Perceval", "Karadoc"]

# %%
camelot["knights"][0]
# Out:
# 'Lancelot'

# %%
camelot.get("hero", "POsition available")
# Out:
# 'POsition available'
