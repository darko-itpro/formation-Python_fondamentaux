# %%
value = "toto"

# %%
try:
    int(value)
except (ValueError, LookupError):
    print("Exception gérée")
except IndexError:
    print("autre chose")
finally:
    print("toujours !!!")
    
print("after")
# Out:
# toujours !!!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 try:
# ----> 2     int(value)
#       3 except IndexError:
#       4     print("Exception gérée")
#
# ValueError: invalid literal for int() with base 10: 'toto'
