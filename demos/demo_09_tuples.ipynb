# %% [markdown]
# ## Tuples (N-uplets)

# %%
value = 1, 2,

# %%
type(value)
# Out:
# tuple

# %%
value = 1,

# %%
value
# Out:
# (1,)

# %%
def truc():
    return 1, 2

# %%
question = 42
answer = "Meaning of life"

# %%
question, answer = answer, question
question, answer = "Meaning of life", 42
question, answer = ("Meaning of life", 42)

# %%
question
# Out:
# 'Meaning of life'
