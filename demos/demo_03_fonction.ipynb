# %% [markdown]
# # Les fonctions

# %%
def say_hello():
    print("Hello World")
    print("To all")

# %%
print(say_hello())
# Out:
# Hello World
# To all
# None

# %%
def give_hello():
    value = "Giving hello"
    return value

# %%
print(give_hello())
# Out:
# Giving hello

# %%
def say_hello_to(name):
    print("Hello", name)

# %%
say_hello_to("Guido")
# Out:
# Hello Guido
