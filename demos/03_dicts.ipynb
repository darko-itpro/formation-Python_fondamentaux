# %% [markdown]
# # Dictionnaires

# %%
type({})
# Out:
# dict

# %%
camelot = {"king": "Arthur", "wizard": "Merlin"}

# %%
len(camelot)
# Out:
# 2

# %%
camelot["king"]
# Out:
# 'Arthur'

# %%
camelot["queen"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 camelot["queen"]
#
# KeyError: 'queen'

# %%
camelot['king'] = "Pendragon"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin'}

# %%
camelot["queen"] = "Gueniever"

# %%
camelot
# Out:
# {'king': 'Pendragon', 'wizard': 'Merlin', 'queen': 'Gueniever'}

# %%
"king" not in camelot
# Out:
# False

# %%
camelot["knights"] = ["Lancelot", "Perceval"]

# %%
camelot
# Out:
# {'king': 'Pendragon',
#  'wizard': 'Merlin',
#  'queen': 'Gueniever',
#  'knights': ['Lancelot', 'Perceval']}

# %%
camelot["knights"][0]
# Out:
# 'Lancelot'
