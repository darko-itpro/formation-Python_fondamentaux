# %% [markdown]
# # La POO

# %%
class MyClass:
    pass

# %%
MyClass()

# %%
class MyClass:
    def __init__(self, new_name):
        self.name = new_name

    def set_name(self, new_name):
        self.name = new_name.title()
    def display_hello(self):
        print("Hello", self.name)

# %%
my_object = MyClass("My name")

# %%
my_object.display_hello()

# %%
my_object.display_hello

# %%
my_object

# %%
MyClass.display_hello(my_object)

# %%
my_object.display_hello()

# %%
class Truk:
    def __init__(self):
        self.name = "bidibidi"

    def display_hello(self):
        for i in range(10):
            print("Hello")

# %%
t = Truk()

# %%
t.name
# Out:
# 'bidibidi'

# %%
t.display_hello()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
my_object.display_hello()
# Out:
# Hello My name

# %%
Truk.display_hello(my_object)
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
class Training:
    def __init__(self, subject, duration, available_seats=12):
        self.subject = subject
        self.duration = duration
        self.available_seats = available_seats
        self.students = []

    def add_student(self, name):
        if len(self.students) >= self.available_seats:
            raise ValueError('training full')

        self.students.append(name)

# %%
pythojn = Training("Python", 5)

# %%
pythojn.available_seats
# Out:
# 12
